# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing


import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn import metrics
import pickle


data1=pd.read_csv('ANN.csv')
data1.head()

x= data1.drop(columns=['UTS',' Yield'])
y=data1[[' Yield']]




from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=42, shuffle=True)


scaler = preprocessing.StandardScaler().fit(x_train)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=1 ,metric='wminkowski',w=2)
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=1:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_1','wb') as f:
    pickle.dump(model,f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9664/2250815285.py in <module>
#       1 from sklearn.neighbors import KNeighborsRegressor
# ----> 2 model = KNeighborsRegressor(n_neighbors=1 ,metric='wminkowski',w=2)
#       3 model.fit(x_train, y_train)
#       4
#       5 y_pred = model.predict(x)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_regression.py in __init__(self, n_neighbors, weights, algorithm, leaf_size, p, metric, metric_params, n_jobs, **kwargs)
#     150                  p=2, metric='minkowski', metric_params=None, n_jobs=None,
#     151                  **kwargs):
# --> 152         super().__init__(
#     153               n_neighbors=n_neighbors,
#     154               algorithm=algorithm,
#
# TypeError: __init__() got an unexpected keyword argument 'w'

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=2 ,metric='canberra')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=2:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_2','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=3 ,metric='canberra')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=3:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_3','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=4 ,metric='canberra')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=4:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_4','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=5 ,metric='canberra')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=5:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_5','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=6 ,metric='canberra')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=6:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_6','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=7 ,metric='minkowski')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=7:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_7','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=8 ,metric='minkowski')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=8:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_8','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=9 ,metric='minkowski')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=9:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_9','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn.neighbors import KNeighborsRegressor
model = KNeighborsRegressor(n_neighbors=10 ,metric='minkowski')
model.fit(x_train, y_train)

y_pred = model.predict(x)
y_predi = model.predict(x)

mape= 100* (metrics.mean_absolute_percentage_error(y, y_pred))
print('Mean Absolute Percentage Error for k=10:', mape , '%')

f=model.score(x,y)
print('coefficient of determination (R^2) =',f)

print(y_pred)

with open('minkowski_saved_10','wb') as f:
    pickle.dump(model,f)

# %%
from sklearn import metrics
from sklearn import neighbors
from sklearn.metrics import mean_squared_error 
from math import sqrt
import matplotlib.pyplot as plt
# %matplotlib inline


rmse_val = [] #to store rmse values for different k
for K in range(10):
    K = K+1
    model = neighbors.KNeighborsRegressor(n_neighbors = K)

    model.fit(x_train, y_train)  #fit the model
    pred=model.predict(x_test) #make prediction on test set
    error = (metrics.mean_absolute_percentage_error(y_test,pred) *100)#calculate rmse
    rmse_val.append(error) #store rmse values
    print('RMSE value for k= ' , K , 'is:', error)
